# %% [markdown]
# # Decentralizing Linguistic Sovereignty: Empirical Evaluation Pipeline
# **Author:** Pegah Merrikhi, PhD
# **Manuscript:** *Decentralizing Linguistic Sovereignty: Evaluating State Space Models and On-Device Edge AI Against Algorithmic Cultural Homogenisation*
#
# This interactive notebook reproduces all statistical analyses, hypothesis testing, and publication figures from the empirical benchmark dataset.

# %%
import sys
import os
sys.path.append('..')

import pandas as pd
import numpy as np
from src.data_loader import load_benchmark_data
from src.statistical_analysis import generate_full_report
from src.visualizations import plot_figure_2_latency, plot_figure_3_correlation

print('Libraries and custom modules loaded.')

# %% [markdown]
# ## 1. Load Empirical Benchmark Data

# %%
df = load_benchmark_data()
df.head()

# %% [markdown]
# ## 2. Statistical Analysis & Hypothesis Testing
# - **Latency Reduction (TTFT):** Wilcoxon Signed-Rank Test & Paired t-test
# - **Effect Size:** Cohen's $d_z$
# - **Algorithmic Homogenisation vs Pragmatic Fidelity:** Spearman $\rho$

# %%
stats_report = generate_full_report(df)
import pprint
pprint.pprint(stats_report)

# %% [markdown]
# ## 3. Publication Figures Generation

# %%
fig2 = plot_figure_2_latency(df)
fig3 = plot_figure_3_correlation(df)
